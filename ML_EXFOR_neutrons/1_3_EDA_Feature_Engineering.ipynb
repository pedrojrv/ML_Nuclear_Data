# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import importlib
import sys
import os

sys.path.append("../../..")
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 50)
pd.options.mode.chained_assignment = None  # default='warn'

import nucml.exfor.data_utilities as exfor_utils
import nucml.plot.plotting_utilities as plot_utils
import nucml.endf.data_utilities as endf_utils
import nucml.datasets as nuc_data
import nucml.endf.plotting_utilities as endf_plot

# %%
importlib.reload(exfor_utils)
importlib.reload(endf_utils)
importlib.reload(plot_utils)
importlib.reload(nuc_data)
importlib.reload(endf_plot)
print("Finish importing scripts.")
# Out:
# Finish importing scripts.

# %%
# Setting up the path where our figures will be stored
figure_dir = "./Figures/"

# %% [markdown]
# # Importing EXFOR and ENDF Data

# %% [markdown]
# ### Loading EXFOR Data

# %%
df = nuc_data.load_exfor()
# Out:
# INFO:root: MODE: neutrons
# INFO:root: LOW ENERGY: False
# INFO:root: LOG: False
# INFO:root: BASIC: -1
# INFO:root: SCALER: STD
# INFO:root:Reading data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\EXFOR\CSV_Files\EXFOR_neutrons\EXFOR_neutrons_MF3_AME_no_RawNaN.csv
# INFO:root:Data read into dataframe with shape: (4255409, 98)
# INFO:root:Finished. Resulting dataset has shape (4255409, 98)

# %%
df.describe(include='all')
# Out:
#        Projectile Target_Metastable_State       MT Product_Metastable_State  \
# count     4255409                 4255409  4255409                  4255409
# unique          1                       4       40                        8
# top       neutron            All_or_Total        1             All_or_Total
# freq      4255409                 4243232  3229171                  4238714
# mean          NaN                     NaN      NaN                      NaN
# std           NaN                     NaN      NaN                      NaN
# min           NaN                     NaN      NaN                      NaN
# 25%           NaN                     NaN      NaN                      NaN
# 50%           NaN                     NaN      NaN                      NaN
# 75%           NaN                     NaN      NaN                      NaN
# max           NaN                     NaN      NaN                      NaN
#
#        EXFOR_Status Center_of_Mass_Flag        Energy       dEnergy  \
# count       4255409             4255409  4.255409e+06  4.255409e+06
# unique            7                   2           NaN           NaN
# top           Other                 Lab           NaN           NaN
# freq        2181990             4250745           NaN           NaN
# mean            NaN                 NaN  2.808464e+06  3.377364e+05
# std             NaN                 NaN  8.814257e+07  3.302129e+07
# min             NaN                 NaN  0.000000e+00  0.000000e+00
# 25%             NaN                 NaN  4.549000e+02  9.351076e+00
# 50%             NaN                 NaN  2.836000e+04  3.944594e+02
# 75%             NaN                 NaN  8.382600e+05  6.240526e+03
# max             NaN                 NaN  1.017000e+11  8.888700e+09
#
#                 Data         dData        ELV/HL       dELV/HL      I78  \
# count   4.255409e+06  4.255409e+06  4.255409e+06  4.255409e+06  4255409
# unique           NaN           NaN           NaN           NaN        6
# top              NaN           NaN           NaN           NaN    Other
# freq             NaN           NaN           NaN           NaN  4116656
# mean    6.373352e+03           inf  5.930286e+04  4.635693e+04      NaN
# std     6.136235e+05           NaN  7.342390e+06  5.151652e+06      NaN
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00      NaN
# 25%     2.577700e+00  9.948200e-02  0.000000e+00  0.000000e+00      NaN
# 50%     5.674200e+00  5.117600e-01  0.000000e+00  0.000000e+00      NaN
# 75%     1.382000e+01  4.801300e+00  0.000000e+00  0.000000e+00      NaN
# max     2.311600e+08           inf  5.545000e+09  3.887880e+09      NaN
#
#                   Short_Reference EXFOR_Accession_Number  \
# count                     4255409                4255409
# unique                       5046                   5477
# top     J.A.Harvey,ET.AL. (88)                     13632
# freq                       186096                 165926
# mean                          NaN                    NaN
# std                           NaN                    NaN
# min                           NaN                    NaN
# 25%                           NaN                    NaN
# 50%                           NaN                    NaN
# 75%                           NaN                    NaN
# max                           NaN                    NaN
#
#         EXFOR_SubAccession_Number EXFOR_Pointer             Z  \
# count                4.255409e+06       4255409  4.255409e+06
# unique                        NaN            16           NaN
# top                           NaN    No Pointer           NaN
# freq                          NaN       4198027           NaN
# mean                 6.279618e+00           NaN  5.322682e+01
# std                  1.183713e+01           NaN  3.231367e+01
# min                  2.000000e+00           NaN  0.000000e+00
# 25%                  2.000000e+00           NaN  2.600000e+01
# 50%                  3.000000e+00           NaN  5.000000e+01
# 75%                  7.000000e+00           NaN  9.200000e+01
# max                  7.210000e+02           NaN  9.900000e+01
#
#           Reaction_Notation                         Title          Year  \
# count               4255409                       4255409  4.255409e+06
# unique                 7493                          5323           NaN
# top     26-FE-0(N,TOT),,SIG  No Title Found. Check EXFOR.           NaN
# freq                 173046                        256144           NaN
# mean                    NaN                           NaN  1.981991e+03
# std                     NaN                           NaN  1.301677e+01
# min                     NaN                           NaN  1.936000e+03
# 25%                     NaN                           NaN  1.972000e+03
# 50%                     NaN                           NaN  1.980000e+03
# 75%                     NaN                           NaN  1.992000e+03
# max                     NaN                           NaN  2.019000e+03
#
#              Author Institute        Date  \
# count       4255409   4255409     4255409
# unique         2903       452        1535
# top     J.A.Harvey+   1USAORL  1997/02/05
# freq         512548   1804518      257947
# mean            NaN       NaN         NaN
# std             NaN       NaN         NaN
# min             NaN       NaN         NaN
# 25%             NaN       NaN         NaN
# 50%             NaN       NaN         NaN
# 75%             NaN       NaN         NaN
# max             NaN       NaN         NaN
#
#                                                 Reference Dataset_Number  \
# count                                             4255409        4255409
# unique                                               5465          26649
# top     Book. Atlas of Neutron Resonances, S.F.Mughabg...       22331004
# freq                                               233874          49709
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#        EXFOR_Entry      Reference_Code  Projectile_Z  Projectile_A  \
# count      4255409             4255409     4255409.0     4255409.0
# unique        5477                5498           NaN           NaN
# top          13632  (B,NEUT.RES,,2006)           NaN           NaN
# freq        165926              233874           NaN           NaN
# mean           NaN                 NaN           0.0           1.0
# std            NaN                 NaN           0.0           0.0
# min            NaN                 NaN           0.0           1.0
# 25%            NaN                 NaN           0.0           1.0
# 50%            NaN                 NaN           0.0           1.0
# 75%            NaN                 NaN           0.0           1.0
# max            NaN                 NaN           0.0           1.0
#
#         Projectile_N  Isotope  Element             N             A  \
# count      4255409.0  4255409  4255409  4.255409e+06  4.255409e+06
# unique           NaN      530       98           NaN           NaN
# top              NaN     56Fe        U           NaN           NaN
# freq             NaN   238200   478297           NaN           NaN
# mean             1.0      NaN      NaN  7.712451e+01  1.303513e+02
# std              0.0      NaN      NaN  5.342918e+01  8.570520e+01
# min              1.0      NaN      NaN  0.000000e+00  1.000000e+00
# 25%              1.0      NaN      NaN  3.000000e+01  5.600000e+01
# 50%              1.0      NaN      NaN  6.900000e+01  1.190000e+02
# 75%              1.0      NaN      NaN  1.420000e+02  2.330000e+02
# max              1.0      NaN      NaN  1.560000e+02  2.550000e+02
#
#        Element_Flag  Nucleus_Radius  Neutron_Nucleus_Radius_Ratio        O  \
# count       4255409    4.255409e+06                  4.255409e+06  4255409
# unique            2             NaN                           NaN       12
# top               I             NaN                           NaN    Other
# freq        3218578             NaN                           NaN  4201804
# mean            NaN    5.934967e+00                  1.488284e-01      NaN
# std             NaN    1.626430e+00                  5.670151e-02      NaN
# min             NaN    1.250000e+00                  1.009253e-01      NaN
# 25%             NaN    4.782328e+00                  1.040067e-01      NaN
# 50%             NaN    6.148356e+00                  1.301161e-01      NaN
# 75%             NaN    7.691812e+00                  1.672825e-01      NaN
# max             NaN    7.926657e+00                  6.400000e-01      NaN
#
#          Mass_Excess  dMass_Excess  Binding_Energy  dBinding_Energy  \
# count   4.255409e+06  4.255409e+06    4.255409e+06     4.255409e+06
# unique           NaN           NaN             NaN              NaN
# top              NaN           NaN             NaN              NaN
# freq             NaN           NaN             NaN              NaN
# mean   -2.180359e+04  5.568818e-01    8.092269e+03    -3.007554e-02
# std     5.017143e+04  9.005086e+00    7.354769e+02     1.248531e+00
# min    -9.165285e+04 -3.088751e+02    0.000000e+00    -4.333629e+01
# 25%    -6.222971e+04  3.020000e-01    7.590914e+03     4.000000e-03
# 50%    -2.926777e+04  7.320000e-01    8.239297e+03     5.000000e-03
# 75%     3.691918e+04  1.146000e+00    8.708456e+03     7.000000e-03
# max     8.408927e+04  1.000000e+02    8.794553e+03     1.162000e+00
#
#         B_Decay_Energy  dB_Decay_Energy  Atomic_Mass_Micro  \
# count     4.255409e+06     4.255409e+06       4.255409e+06
# unique             NaN              NaN                NaN
# top                NaN              NaN                NaN
# freq               NaN              NaN                NaN
# mean     -2.913318e+03     7.252719e+00       1.303370e+08
# std       3.699096e+03     8.338442e+01       8.573942e+07
# min      -2.289827e+04    -7.911077e+02       1.007000e+06
# 25%      -4.056340e+03     4.430000e-01       5.584500e+07
# 50%      -1.452000e+03     1.496000e+00       1.187100e+08
# 75%      -5.272525e+02     3.428000e+00       2.330396e+08
# max       1.600413e+04     2.000000e+03       2.550903e+08
#
#         dAtomic_Mass_Micro         S(2n)        dS(2n)         S(2p)  \
# count         4.255409e+06  4.255409e+06  4.255409e+06  4.255409e+06
# unique                 NaN           NaN           NaN           NaN
# top                    NaN           NaN           NaN           NaN
# freq                   NaN           NaN           NaN           NaN
# mean          5.974024e-01  1.759613e+04  3.185743e+00  1.604030e+04
# std           9.668615e+00  5.388592e+03  6.441949e+01  4.191867e+03
# min          -3.316373e+02  0.000000e+00 -7.940390e+02  0.000000e+00
# 25%           3.240000e-01  1.264607e+04  2.550000e-01  1.239081e+04
# 50%           7.855000e-01  1.646771e+04  8.400000e-01  1.541320e+04
# 75%           1.230000e+00  2.038701e+04  1.980000e+00  1.895017e+04
# max           1.070000e+02  3.751200e+04  2.003000e+03  3.663581e+04
#
#               dS(2p)          Q(a)         dQ(a)        Q(2B-)       dQ(2B-)  \
# count   4.255409e+06  4.255409e+06  4.255409e+06  4.255409e+06  4.255409e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    5.339467e+00 -2.088970e+03  1.214953e+00 -7.193361e+03  4.276613e+01
# std     1.498080e+01  5.624606e+03  2.711211e+00  8.254617e+03  2.018076e+02
# min     0.000000e+00 -1.397629e+04  0.000000e+00 -5.325021e+04 -2.317404e+02
# 25%     3.600000e-01 -7.366590e+03  2.100000e-01 -9.032660e+03  1.220000e+00
# 50%     1.170000e+00 -2.500985e+03  5.400000e-01 -3.968400e+03  5.120000e+00
# 75%     3.700000e+00  4.557410e+03  1.180000e+00 -1.782420e+03  2.618500e+01
# max     3.590000e+02  7.160000e+03  1.960000e+02  1.251469e+04  2.003000e+03
#
#                Q(ep)        dQ(ep)        Q(B-n)       dQ(B-n)          S(n)  \
# count   4.255409e+06  4.255409e+06  4.255409e+06  4.255409e+06  4.255409e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# m
# 25%    -4.074932e+03  9.981889e+03  1.028975e+04
# 50%    -1.470592e+03  1.250527e+04  1.230505e+04
# 75%    -5.458445e+02  1.420201e+04  1.333921e+04
# max     1.598554e+04  2.057762e+04  1.981386e+04

# %% [markdown]
# # Exploratory Data Analysis
#
# Let us study the dataset and analyze the distributions.

# %%
sns.set(font_scale=1)
sns.set_style("white")

# %% [markdown]
# We can see that several features are extremeley negatively skewed. This introduces problems to almost all ML algorithms as we shall demonstrate in the next notebook.

# %%
from scipy.stats import skew

# %% [markdown]
# - skewness = 0 : normally distributed.
# - skewness > 0 : more weight in the left tail of the distribution.
# - skewness < 0 : more weight in the right tail of the distribution.

# %%
numerical_columns = df.select_dtypes(include=['float64']).columns

# %%
case_list = {}

for col in numerical_columns:
    skewness = skew(df[col].values)
    case = {col: skewness}
    case_list.update(case)
    
skew_df = pd.Series(case_list).to_frame().reset_index()
skew_df.columns = ["Column_Name", "Skewness"]
skew_df = skew_df.sort_values(by=["Skewness"], ascending=False)
# Out:
# C:\Users\Pedro\Anaconda3\envs\data_mining_gpu\lib\site-packages\scipy\stats\stats.py:1082: RuntimeWarning: invalid value encountered in subtract
#   a_zero_mean = a - np.expand_dims(np.mean(a, axis), axis)

# %%
print(skew_df.to_latex(index=False))
# Out:
# \begin{tabular}{lr}
# \toprule
#                   Column\_Name &    Skewness \\
# \midrule
#                        ELV/HL &  724.315247 \\
#                       dELV/HL &  722.899187 \\
#                        Energy &  689.584529 \\
#                       dEnergy &  164.811156 \\
#                          Data &  139.742977 \\
#                        dS(2n) &   18.848509 \\
#               dB\_Decay\_Energy &   18.374140 \\
#                       dQ(4B-) &   13.804831 \\
#                       dQ(d,a) &   13.125649 \\
#                       dQ(n,a) &   11.654097 \\
#                       dQ(B-n) &    8.350713 \\
#                       dQ(2B-) &    8.238419 \\
#                         dQ(a) &    7.692839 \\
#                        dS(2p) &    7.268825 \\
#                         dS(p) &    6.330616 \\
#                        dQ(ep) &    4.868759 \\
#  Neutron\_Nucleus\_Radius\_Ratio &    2.652843 \\
#                         S(2n) &    1.001953 \\
#                          S(p) &    1.001594 \\
#                         S(2p) &    0.789946 \\
#                          S(n) &    0.738252 \\
#                   Mass\_Excess &    0.313934 \\
#             Atomic\_Mass\_Micro &    0.122137 \\
#                          Q(a) &    0.071802 \\
#                        Q(g,a) &    0.071802 \\
#                      Q(g,He3) &   -0.004890 \\
#                       Q(g,pn) &   -0.007570 \\
#                        Q(g,d) &   -0.007625 \\
#                      Q(p,3He) &   -0.007695 \\
#                        Q(n,t) &   -0.007699 \\
#                        Q(d,a) &   -0.007727 \\
#                        Q(n,a) &   -0.056553 \\
#                Nucleus\_Radius &   -0.362292 \\
#                        Q(g,t) &   -0.365110 \\
#                        Q(p,a) &   -0.365147 \\
#                        Q(p,d) &   -0.738252 \\
#                       Q(n,2n) &   -0.738252 \\
#                        Q(g,n) &   -0.738252 \\
#                       Q(p,pn) &   -0.738252 \\
#                        Q(d,t) &   -0.738252 \\
#                      Q(3He,a) &   -0.738252 \\
#                       Q(g,2p) &   -0.789946 \\
#                      Q(n,3He) &   -0.933966 \\
#                       Q(p,2p) &   -1.001594 \\
#                        Q(g,p) &   -1.001594 \\
#                       Q(n,np) &   -1.001594 \\
#                        Q(n,d) &   -1.001668 \\
#                      Q(d,3He) &   -1.001710 \\
#                        Q(t,a) &   -1.001902 \\
#                       Q(g,2n) &   -1.001953 \\
#                        Q(p,t) &   -1.002031 \\
#                       Q(p,2n) &   -1.593202 \\
#                        Q(B-n) &   -1.593206 \\
#                        Q(4B-) &   -1.677550 \\
#                         Q(ep) &   -1.696255 \\
#                       Q(n,2p) &   -1.711368 \\
#                        Q(2B-) &   -1.715373 \\
#                B\_Decay\_Energy &   -1.924420 \\
#                        Q(p,n) &   -1.924420 \\
#                      Q(3He,t) &   -1.924420 \\
#                Binding\_Energy &   -3.828846 \\
#                       dQ(p,a) &  -10.745118 \\
#                         dS(n) &  -15.470355 \\
#                  dMass\_Excess &  -33.615352 \\
#            dAtomic\_Mass\_Micro &  -33.616298 \\
#               dBinding\_Energy &  -34.655970 \\
#                         dData &         NaN \\
# \bottomrule
# \end{tabular}

# %%
# In addition to all uncertanties
# skewed_cols = ["Binding_Energy", "ELV/HL", "Energy", "dBinding_Energy", "dELV/HL", "dEnergy"]
skewed_cols = ["Energy", "dEnergy"]

# %%
energy_log = np.log10(df["Energy"].values)
energy_ln = np.log(df["Energy"].values)

# %%
df[["Energy"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000190D1AAB1D0>]],
#       dtype=object)

# %%
plt.hist(energy_ln)
plt.show()

# %%
for col in skewed_cols:
    log_values = np.log10(df[col].values)
    df[col] = log_values

# %%
df["Year"] = df["Year"].astype(int)

# %% [markdown]
# # Categorical Data

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant is our calculated score value.</p>
#
# <p>If our data variable is strongly correlated with the variable we are analyzing, expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %%
grouped_test = df[['MT', 'Data']].groupby(['MT'])

f_val, p_val = stats.f_oneway(grouped_test.get_group("1")['Data'], grouped_test.get_group('101')['Data'], grouped_test.get_group('102')['Data'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 15917.016298247428 , P = 0.0

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation and a P value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?

# %%
def box_plot(x, dataframe=df, figsize=(8,6)):
    plt.figure(figsize=figsize)
    sns.boxplot(x=x, y="Data", data=dataframe)

# %%
box_plot("MT", figsize=(18,10))

# %% [markdown]
# The values for other reaction types get squashed do the large magnitude of fission and total cross section data points (MT1 and MT101). Still it is noticable that these cross sections are magnitudes higher than other types. This feature will be helpful in determining limits to some reaction types (it will learn not to go above certan values.

# %%
# call regplot on each axes
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18,10))
sns.boxplot(x="Frame", y="Data", data=df, ax=ax1)
sns.boxplot(x="Target_Meta_State", y="Data", data=df, ax=ax2)
sns.boxplot(x="Product_Meta_State", y="Data", data=df, ax=ax3)
