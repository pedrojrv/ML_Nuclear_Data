# %%
import pandas as pd
import os
import sys
sys.path.append("..")

import shutil

# %%
import nucml.model.model_utilities as model_utils

# %%
knn_results = pd.read_csv("1_KNN/knn_results_B0.csv")

# %%
knn_results
# Out:
#     id distance_metric mt_strategy normalizer  train_mae  train_mse  \
# 0    1       euclidean     one_hot   standard   0.029223   0.021718
# 1    1       manhattan     one_hot   standard   0.029223   0.021718
# 2   13       euclidean     one_hot   standard   0.025784   0.010824
# 3    9       euclidean     one_hot   standard   0.025882   0.010964
# 4    5       euclidean     one_hot   standard   0.026087   0.011288
# ..  ..             ...         ...        ...        ...        ...
# 75  12       euclidean     one_hot     robust   0.025880   0.010948
# 76   8       manhattan     one_hot     robust   0.025963   0.011088
# 77   4       manhattan     one_hot     robust   0.026250   0.011546
# 78  20       manhattan     one_hot     robust   0.025800   0.010808
# 79  12       manhattan     one_hot     robust   0.025880   0.010948
#
#     train_evs  train_mae_m  train_r2   val_mae  ...    val_r2  test_mae  \
# 0    0.972236          0.0  0.972236  0.140906  ...  0.881658  0.140439
# 1    0.972236          0.0  0.972236  0.140310  ...  0.883701  0.139807
# 2    0.985956          0.0  0.985956  0.119711  ...  0.914196  0.119358
# 3    0.985770          0.0  0.985770  0.118556  ...  0.915178  0.118580
# 4    0.985375          0.0  0.985375  0.120315  ...  0.913349  0.119268
# ..        ...          ...       ...       ...  ...       ...       ...
# 75   0.985804          0.0  0.985804  0.120741  ...  0.911355  0.121507
# 76   0.985625          0.0  0.985625  0.118417  ...  0.915453  0.118021
# 77   0.985051          0.0  0.985051  0.121491  ...  0.911322  0.120564
# 78   0.985973          0.0  0.985973  0.121384  ...  0.911571  0.120190
# 79   0.985804          0.0  0.985804  0.118508  ...  0.915665  0.119360
#
#     test_mse  test_evs  test_mae_m   test_r2  \
# 0   0.090714  0.882881    0.047626  0.882880
# 1   0.089210  0.884837    0.047548  0.884835
# 2   0.063235  0.915548    0.042613  0.915548
# 3   0.062984  0.916367    0.041561  0.916367
# 4   0.064523  0.913552    0.041247  0.913552
# ..       ...       ...         ...       ...
# 75  0.067982  0.909173    0.042693  0.909173
# 76  0.062797  0.916661    0.041616  0.916661
# 77  0.067829  0.910530    0.041199  0.910530
# 78  0.063742  0.915290    0.043563  0.915287
# 79  0.065161  0.913195    0.042154  0.913195
#
#                                            model_path  training_time  \
# 0   E:\ML_Models_EXFOR\KNN_B0\k1_distance_euclidea...    3204.087972
# 1   E:\ML_Models_EXFOR\KNN_B0\k1_distance_manhatta...    3683.483599
# 2   E:\ML_Models_EXFOR\KNN_B0\k13_distance_euclide...    3842.479054
# 3   E:\ML_Models_EXFOR\KNN_B0\k9_distance_euclidea...    5248.473446
# 4   E:\ML_Models_EXFOR\KNN_B0\k5_distance_euclidea...    4999.680279
# ..                                                ...            ...
# 75  E:\ML_Models_EXFOR\KNN_B0\k12_distance_euclide...    6956.197334
# 76  E:\ML_Models_EXFOR\KNN_B0\k8_distance_manhatta...    5606.621590
# 77  E:\ML_Models_EXFOR\KNN_B0\k4_distance_manhatta...    6074.617433
# 78  E:\ML_Models_EXFOR\KNN_B0\k20_distance_manhatt...    5845.332301
# 79  E:\ML_Models_EXFOR\KNN_B0\k12_distance_manhatt...    5585.601369
#
#                                           scaler_path  \
# 0   E:\ML_Models_EXFOR\KNN_B0\k1_distance_euclidea...
# 1   E:\ML_Models_EXFOR\KNN_B0\k1_distance_manhatta...
# 2   E:\ML_Models_EXFOR\KNN_B0\k13_distance_euclide...
# 3   E:\ML_Models_EXFOR\KNN_B0\k9_distance_euclidea...
# 4   E:\ML_Models_EXFOR\KNN_B0\k5_distance_euclidea...
# ..                                                ...
# 75  E:\ML_Models_EXFOR\KNN_B0\k12_distance_euclide...
# 76  E:\ML_Models_EXFOR\KNN_B0\k8_distance_manhatta...
# 77  E:\ML_Models_EXFOR\KNN_B0\k4_distance_manhatta...
# 78  E:\ML_Models_EXFOR\KNN_B0\k20_distance_manhatt...
# 79  E:\ML_Models_EXFOR\KNN_B0\k12_distance_manhatt...
#
#                                          run_name
# 0    k1_distance_euclidean_standard_one_hot_B0_v1
# 1    k1_distance_manhattan_standard_one_hot_B0_v1
# 2   k13_distance_euclidean_standard_one_hot_B0_v1
# 3    k9_distance_euclidean_standard_one_hot_B0_v1
# 4    k5_distance_euclidean_standard_one_hot_B0_v1
# ..                                            ...
# 75    k12_distance_euclidean_robust_one_hot_B0_v1
# 76     k8_distance_manhattan_robust_one_hot_B0_v1
# 77     k4_distance_manhattan_robust_one_hot_B0_v1
# 78    k20_distance_manhattan_robust_one_hot_B0_v1
# 79    k12_distance_manhattan_robust_one_hot_B0_v1
#
# [80 rows x 23 columns]

# %%
best_models = model_utils.get_best_models_df(knn_results)

# %%
best_models
# Out:
#     id distance_metric mt_strategy normalizer  train_mae  train_mse  \
# 28  16       euclidean     one_hot   standard   0.025762   0.010797
# 33  16       manhattan     one_hot   standard   0.025762   0.010797
# 9    9       manhattan     one_hot   standard   0.025882   0.010964
# 37   8       manhattan     one_hot   standard   0.025939   0.011031
#
#     train_evs  train_mae_m  train_r2   val_mae  ...  test_mae  test_mse  \
# 28   0.985991          0.0  0.985991  0.120330  ...  0.119925  0.063432
# 33   0.985991          0.0  0.985991  0.118842  ...  0.118412  0.061384
# 9    0.985770          0.0  0.985770  0.117340  ...  0.117377  0.061497
# 37   0.985707          0.0  0.985707  0.117952  ...  0.117185  0.061773
#
#     test_evs  test_mae_m   test_r2  \
# 28  0.915093    0.043245  0.915092
# 33  0.917932    0.042845  0.917931
# 9   0.918433    0.041257  0.918433
# 37  0.916968    0.041113  0.916968
#
#                                            model_path  training_time  \
# 28  E:\ML_Models_EXFOR\KNN_B0\k16_distance_euclide...    5255.165533
# 33  E:\ML_Models_EXFOR\KNN_B0\k16_distance_manhatt...    5162.847080
# 9   E:\ML_Models_EXFOR\KNN_B0\k9_distance_manhatta...    5361.724394
# 37  E:\ML_Models_EXFOR\KNN_B0\k8_distance_manhatta...    4762.610942
#
#                                           scaler_path  \
# 28  E:\ML_Models_EXFOR\KNN_B0\k16_distance_euclide...
# 33  E:\ML_Models_EXFOR\KNN_B0\k16_distance_manhatt...
# 9   E:\ML_Models_EXFOR\KNN_B0\k9_distance_manhatta...
# 37  E:\ML_Models_EXFOR\KNN_B0\k8_distance_manhatta...
#
#                                          run_name    tag
# 28  k16_distance_euclidean_standard_one_hot_B0_v1  Train
# 33  k16_distance_manhattan_standard_one_hot_B0_v1  Train
# 9    k9_distance_manhattan_standard_one_hot_B0_v1    Val
# 37   k8_distance_manhattan_standard_one_hot_B0_v1   Test
#
# [4 rows x 24 columns]

# %%
best_models.model_path.values[0]
# Out:
# 'E:\\ML_Models_EXFOR\\KNN_B0\\k16_distance_euclidean_standard_one_hot_B0_v1\\k16_distance_euclidean_standard_one_hot_B0_v1.joblib'

# %%
# model_utils.cleanup_model_dir(knn_results, "E:/ML_Models_EXFOR/DT_B0/")
