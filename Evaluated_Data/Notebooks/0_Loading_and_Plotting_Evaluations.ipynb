# %%
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
import sys
import os

sys.path.append("../../")

import nucml.evaluation.plotting_utilities as eval_plot
import nucml.evaluation.data_utilities as eval_utils
import nucml.datasets as nuc_data

# %%
importlib.reload(eval_plot)
importlib.reload(nuc_data)
importlib.reload(eval_utils)
print("Finish reloading scripts.")
# Out:
# Finish reloading scripts.

# %%
figure_dir = "Figures/"

# %%
chlorine_np = nuc_data.load_evaluation("cl35", 103)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/endfb8.0/tables/xs/n-Cl035-MT103.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 8791 datapoints.

# %%
eval_plot.plot("Cl35", 103, exclude=["jeff"], save=True, save_dir=figure_dir)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/endfb8.0/tables/xs/n-Cl035-MT103.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 8791 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/tendl.2019/tables/xs/n-Cl035-MT103.tendl.2019
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 592 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/jendl4.0/tables/xs/n-Cl035-MT103.jendl4.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 2130 datapoints.
# ...

# %%
eval_plot.plot("Cl035", "102", exclude=["jeff"], save=True, save_dir=figure_dir)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/endfb8.0/tables/xs/n-Cl035-MT102.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 28950 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/tendl.2019/tables/xs/n-Cl035-MT102.tendl.2019
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 13066 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Cl035/jendl4.0/tables/xs/n-Cl035-MT102.jendl4.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 13111 datapoints.
# ...

# %%
eval_plot.plot("Fe056", "102", save=True, save_dir=figure_dir)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Fe056/endfb8.0/tables/xs/n-Fe056-MT102.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 45284 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Fe056/tendl.2019/tables/xs/n-Fe056-MT102.tendl.2019
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 45178 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/Fe056/jendl4.0/tables/xs/n-Fe056-MT102.jendl4.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 45128 datapoints.
# ...

# %%
eval_plot.plot("U233", "018", save=True, save_dir=figure_dir)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U233/endfb8.0/tables/xs/n-U233-MT018.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 15345 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U233/tendl.2019/tables/xs/n-U233-MT018.tendl.2019
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 15345 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U233/jendl4.0/tables/xs/n-U233-MT018.jendl4.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 15341 datapoints.
# ...

# %%
eval_plot.plot("U233", "002", save=True, save_dir=figure_dir)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U233/endfb8.0/tables/xs/n-U233-MT002.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 5590 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U233/tendl.2019/tables/xs/n-U233-MT002.tendl.2019
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 5590 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U233/jendl4.0/tables/xs/n-U233-MT002.jendl4.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 5585 datapoints.
# ...

# %%
eval_plot.plot("U235", "018", save=True, save_dir=figure_dir)
# Out:
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U235/endfb8.0/tables/xs/n-U235-MT018.endfb8.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 46678 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U235/tendl.2019/tables/xs/n-U235-MT018.tendl.2019
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 46678 datapoints.
# INFO:root:EVALUATION: Extracting data from C:\Users\Pedro\Desktop\ML_Nuclear_Data\Evaluated_Data\neutrons/U235/jendl4.0/tables/xs/n-U235-MT018.jendl4.0
# INFO:root:EVALUATION: Converting MeV to eV...
# INFO:root:EVALUATION: Converting mb to b...
# INFO:root:EVALUATION: Finished. ENDF data contains 21076 datapoints.
# ...
