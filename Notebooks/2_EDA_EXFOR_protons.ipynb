# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 50)
pd.options.mode.chained_assignment = None  # default='warn'

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import importlib

# %%
sns.set_style("darkgrid")

# %%
from Utilities import EXFOR_utilities as exfor_utils
from Utilities import ENDF_utilities as endf_utils
from Utilities import Plotting_utilities as plot_utils
importlib.reload(exfor_utils)
importlib.reload(endf_utils)
print("Finish importing scripts.")
# Out:
# Finish importing scripts.

# %%
df = exfor_utils.load_exfor("../ML_Data/working_p_xs_v2.csv")
# Out:
# Reading data into dataframe...
# Data read into dataframe with shape:  (137679, 66)
# Finished. Resulting dataset has shape  (137679, 66)

# %%
df.columns
# Out:
# Index(['Target_Meta_State', 'MT', 'Energy', 'dEnergy', 'Data', 'dData',
#        'ELV/HL', 'dELV/HL', 'I78', 'EntrySubP', 'Target_Protons',
#        'Product_Meta_State', 'EXFOR_Status', 'Frame', 'Reaction_Notation',
#        'Title', 'Year', 'Institute', 'Date', 'Reference', 'Out',
#        'Target_Neutrons', 'Target_Mass_Number', 'Target_Element',
#        'Target_Flag', 'Target_Element_w_A', 'Target_Radius',
#        'Prot_Nuc_Rad_Ratio', 'Target_Origin', 'Target_Mass_Excess',
#        'Target_dMass_Excess', 'Target_Binding_Energy',
#        'Target_dBinding_Energy', 'Target_B_Decay_Energy',
#        'Target_dB_Decay_Energy', 'Target_Atomic_Mass_Micro',
#        'Target_dAtomic_Mass_Micro', 'Target_S(2n)', 'Target_dS(2n)',
#        'Target_S(2p)', 'Target_dS(2p)', 'Target_S(n)', 'Target_dS(n)',
#        'Target_S(p)', 'Target_dS(p)', 'Compound_Neutrons',
#        'Compound_Mass_Number', 'Compound_Protons', 'Compound_EL',
#        'Compound_Origin', 'Compound_Mass_Excess', 'Compound_dMass_Excess',
#        'Compound_Binding_Energy', 'Compound_dBinding_Energy',
#        'Compound_B_Decay_Energy', 'Compound_dB_Decay_Energy',
#        'Compound_Atomic_Mass_Micro', 'Compound_dAtomic_Mass_Micro',
#        'Compound_S(2n)', 'Compound_dS(2n)', 'Compound_S(2p)',
#        'Compound_dS(2p)', 'Compound_S(n)', 'Compound_dS(n)', 'Compound_S(p)',
#        'Compound_dS(p)'],
#       dtype='object')

# %%
df.shape
# Out:
# (137679, 66)

# %%
df.MT.value_counts()
# Out:
# 9000    50723
# 9001    27886
# 4       27574
# 16       5602
# 102      4974
# 107      3934
# 17       3420
# 18       2996
# 51       2836
# 37       1866
# 3        1209
# 152      1058
# 28        982
# 111       558
# 106       464
# 103       316
# 153       270
# 22        208
# 108       136
# 104       127
# 160        87
# 198        70
# 42         49
# 41         45
# 190        43
# 24         41
# 45         41
# 156        30
# 105        28
# 44         23
# 179        21
# 29         10
# 109         8
# 165         6
# 25          5
# 23          5
# 1003        4
# 115         3
# 161         3
# 191         3
# 112         3
# 117         2
# 116         2
# 193         2
# 192         2
# 168         1
# 162         1
# 114         1
# 155         1
# Name: MT, dtype: int64

# %%
df[df.Reaction_Notation.str.contains("P,X")]
# Out:
#        Target_Meta_State    MT       Energy       dEnergy          Data  \
# 16                   All  9000  585000000.0  2.000000e+06  9.700000e-03
# 17                   All  9000  730000000.0  1.868734e+07  1.350000e-02
# 18                   All  9000  730000000.0  1.868734e+07  3.000000e-05
# 166                  All  9000   10000000.0  2.559910e+05  1.000000e-01
# 167                  All  9000   20000000.0  5.119819e+05  1.180000e-01
# ...                  ...   ...          ...           ...           ...
# 137532               All  9001   17500000.0  2.557446e+05  1.750000e-02
# 137533               All  9001  660000000.0  9.645223e+06  1.700000e-03
# 137534               All  9001  660000000.0  9.645223e+06  3.310000e-03
# 137535               All  9001  660000000.0  9.645223e+06  2.526000e-02
# 137671               All  9000   10300000.0  2.636707e+05  4.000000e-09
#
#           dData  ELV/HL  dELV/HL    I78 EntrySubP  Target_Protons  \
# 16      0.00120     0.0      0.0  Other     O0156               1
# 17      0.00073     0.0      0.0  Other     C1754               1
# 18      0.00001     0.0      0.0  Other     C1754               1
# 166         inf     0.0      0.0  Other     A0033               1
# 167         inf     0.0      0.0  Other     A0033               1
# ...         ...     ...      ...    ...       ...             ...
# 137532  0.00040     0.0      0.0  Other     A0528              93
# 137533  0.00020     0.0      0.0  Other     F1232              93
# 137534  0.00030     0.0      0.0  Other     O0842              93
# 137535  0.00300     0.0      0.0  Other     O0842              93
# 137671      inf     0.0      0.0  Other     O2042              95
#
#        Product_Meta_State EXFOR_Status Frame  \
# 16                    All        Other     L
# 17                    All            D     L
# 18                    All            D     L
# 166                   All            A     L
# 167                   All            A     L
# ...                   ...          ...   ...
# 137532                All        Other     L
# 137533                  +            A     L
# 137534                All        Other     L
# 137535                All        Other     L
# 137671                  L        Other     L
#
#                           Reaction_Notation  \
# 16                    1-H-1(P,X)1-PP-0,,SIG
# 17                    1-H-1(P,X)1-PP-0,,SIG
# 18                    1-H-1(P,X)1-PN-0,,SIG
# 166            1-H-2(P,X)0-NN-1,,SIG,,,EVAL
# 167            1-H-2(P,X)0-NN-1,,SIG,,,EVAL
# ...                                     ...
# 137532      93-NP-237(P,X)94-PU-236,CUM,SIG
# 137533  93-NP-237(P,X)27-CO-60-G+M1,CUM,SIG
# 137534      93-NP-237(P,X)63-EU-148,CUM,SIG
# 137535      93-NP-237(P,X)65-TB-152,CUM,SIG
# 137671       95-AM-241(P,X)95-AM-240-L,,SIG
#
#                                                     Title  Year  Institute  \
# 16      Measurement of cross sections and asymmetry pa...  1980  (2SWTPSI)
# 17      Production of charged pions by 730-MeV protons...  1972  (1USALAS)
# 18      Production of charged pions by 730-MeV protons...  1972  (1USALAS)
# 166     Cross sections of neutron emission in the p-d ...  1978  (4ZZZDUB)
# 167     Cross sections of neutron emission in the p-d ...  1978  (4ZZZDUB)
# ...                                                   ...   ...        ...
# 137532  Formation of Pu-236 and Pu-237 by proton-induc...  1993  (2SF HLS)
# 137533  Superasymmetric fission of heavy nuclei induce...  2013  (3BZLUSP)
# 137534  Results of investigation of proton-nuclear rea...  2000  (4ZZZDUB)
# 137535  Results of investigation of proton-nuclear rea...  2000  (4ZZZDUB)
# 137671  Excitation energy of the spontaneously fission...  1967  (2DENCOP)
#
#             Date                                          Reference Out  \
# 16      20100704  J.F.Crawford+ Jour. Physical Review, Part C, N...   X
# 17      20091104  D.R.F.Cochran+ Jour. Physical Review, Part D, ...   X
# 18      20091104  D.R.F.Cochran+ Jour. Physical Review, Part D, ...   X
# 166     20190602  G.I.Lykasov Rept. Joint Inst. for Nucl. Res., ...   X
# 167     20190602  G.I.Lykasov Rept. Joint Inst. for Nucl. Res., ...   X
# ...          ...                                                ...  ..
# 137532  20160304  J.Aaltonen+ Jour. Physical Review, Part C, Nuc...   X
# 137533  20140905  A.Deppman+ Conf. Conf.Nucl.Spectr.Nucl.Struct....   X
# 137534  20131004  J.Adam+ Conf. Conf.Nucl.Spectr.Nucl.Struct.,St...   X
# 137535  20131004  J.Adam+ Jour. Physical Review, Part C, Nuclear...   X
# 137671  20120902  S.Bjoernholm+ Jour. Physical Review, Part C, N...   X
#
#         Target_Neutrons  Target_Mass_Number Target_Element Target_Flag  \
# 16                    0                   1              H           I
# 17                    0                   1              H           I
# 18                    0                   1              H           I
# 166                   1                   2              H           I
# 167                   1                   2              H           I
# ...                 ...                 ...            ...         ...
# 137532              144                 237             Np           I
# 137533              144                 237             Np           I
# 137534              144                 237             Np           I
# 137535              144                 237             Np           I
# 137671              146                 241             Am           I
#
#        Target_Element_w_A  Target_Radius  Prot_Nuc_Rad_Ratio Target_Origin  \
# 16                     1H       1.250000            0.640000         Other
# 17                     1H       1.250000            0.640000         Other
# 18                     1H       1.250000            0.640000         Other
# 166                    2H       1.574901            0.507968         Other
# 167                    2H       1.574901            0.507968         Other
# ...                   ...            ...                 ...           ...
# 137532              237Np       7.735578            0.103418         Other
# 137533              237Np       7.735578            0.103418         Other
# 137534              237Np       7.735578            0.103418         Other
# 137535              237Np       7.735578            0.103418         Other
# 137671              241Am       7.778855            0.102843         Other
#
#         Target_Mass_Excess  Target_dMass_Excess  Target_Binding_Energy  \
# 16              7288.97061              0.00009                  0.000
# 17              7288.97061              0.00009                  0.000
# 18              7288.97061              0.00009                  0.000
# 166            13135.72176              0.00011               1112.283
# 167            13135.72176              0.00011               1112.283
# ...                    ...                  ...                    ...
# 137532         44871.65900              1.12000               7574.989
# 137533         44871.65900              1.12000               7574.989
# 137534         44871.65900              1.12000               7574.989
# 137535         44871.65900              1.12000               7574.989
# 137671         52934.39500              1.11400               7543.278
#
#         Target_dBinding_Energy  Target_B_Decay_Energy  Target_dB_Decay_Energy  \
# 16                       0.000              18244.328                289.9558
# 17                       0.000              18244.328                289.9558
# 18                       0.000              18244.328                289.9558
# 166                      0.000              18244.328                289.9558
# 167                      0.000              18244.328                289.9558
# ...                        ...                    ...                     ...
# 137532                   0.005               -220.063                  1.2940
# 137533                   0.005               -220.063                  1.2940
# 137534                   0.005               -220.063                  1.2940
# 137535                   0.005               -220.063                  1.2940
# 137671                   0.005               -767.434                  1.1680
#
#         Target_Atomic_Mass_Micro  Target_dAtomic_Mass_Micro  Target_S(2n)  \
# 16                  1.007825e+06                    0.00009      2025.412
# 17                  1.007825e+06                    0.00009      2025.412
# 18                  1.007825e+06                    0.00009      2025.412
# 166                 2.014102e+06                    0.00012      2025.412
# 167                 2.014102e+06                    0.00012      2025.412
# ...                          ...                        ...           ...
# 137532              2.370482e+08                    1.20200     12314.080
# 137533              2.370482e+08                    1.20200     12314.080
# 137534              2.370482e+08                    1.20200     12314.080
# 137535              2.370482e+08                    1.20200     12314.080
# 137671              2.410568e+08                    1.19500     12598.660
#
#         Target_dS(2n)  Target_S(2p)  Target_dS(2p)  Target_S(n)  Target_dS(n)  \
# 16            292.506  13771.880283     158.524008  1096.973333       256.595
# 17            292.506  13771.880283     158.524008  1096.973333       256.595
# 18            292.506  13771.880283     158.524008  1096.973333       256.595
# 166           292.506  13771.880283     158.524008  2224.570000         0.000
# 167           292.506  13771.880283     158.524008  2224.570000         0.000
# ...               ...           ...            ...          ...           ...
# 137532          0.910  11995.180000      14.020000  6577.840000        50.420
# 137533          0.910  11995.180000      14.020000  6577.840000        50.420
# 137534          0.910  11995.180000      14.020000  6577.840000        50.420
# 137535          0.910  11995.180000      14.020000  6577.840000        50.420
# 137671          1.680  10954.600000       0.970000  6647.090000        13.790
#
#         Target_S(p)  Target_dS(p)  Compound_Neutrons  Compound_Mass_Number  \
# 16             0.00          0.00                  1                     2
# 17             0.00          0.00                  1                     2
# 18             0.00          0.00                  1                     2
# 166         2224.57          0.00                  2                     3
# 167         2224.57          0.00                  2                     3
# ...             ...           ...                ...                   ...
# 137532      4861.95          0.25                145                   238
# 137533      4861.95          0.25                145                   238
# 137534      4861.95          0.25                145                   238
# 137535      4861.95          0.25                145                   238
# 137671      4479.96          0.17                147                   242
#
#         Compound_Protons Compound_EL Compound_Origin  Compound_Mass_Excess  \
# 16                     1           H           Other           13135.72176
# 17                     1           H           Other           13135.72176
# 18                     1           H           Other           13135.72176
# 166                    1           H           Other           14949.80993
# 167                    1           H           Other           14949.80993
# ...                  ...         ...             ...                   ...
# 137532                93          Np              -n           47454.65600
# 137533                93          Np              -n           47454.65600
# 137534                93          Np              -n           47454.65600
# 137535                93          Np              -n           47454.65600
# 137671                95          Am              -n           55468.07200
#
#         Compound_dMass_Excess  Compound_Binding_Energy  \
# 16                    0.00011                 1112.283
# 17                    0.00011                 1112.283
# 18                    0.00011                 1112.283
# 166                   0.00022                 2827.265
# 167                   0.00022                 2827.265
# ...                       ...                      ...
# 137532                1.13800                 7566.221
# 137533                1.13800                 7566.221
# 137534                1.13800                 7566.221
# 137535                1.13800                 7566.221
# 137671                1.11900                 7534.991
#
#         Compound_dBinding_Energy  Compound_B_Decay_Energy  \
# 16                         0.000                18244.328
# 17                         0.000                18244.328
# 18                         0.000                18244.328
# 166                        0.000                   18.592
# 167                        0.000                   18.592
# ...                          ...                      ...
# 137532                     0.005                 1291.443
# 137533                     0.005                 1291.443
# 137534                     0.005                 1291.443
# 137535                     0.005                 1291.443
# 137671                     0.005                  664.309
#
#         Compound_dB_Decay_Energy  Compound_Atomic_Mass_Micro  \
# 16                      289.9558                2.014102e+06
# 17                      289.9558                2.014102e+06
# 18                      289.9558                2.014102e+06
# 166                       0.0000                3.016049e+06
# 167                       0.0000                3.016049e+06
# ...                          ...                         ...
# 137532                    0.4570                2.380509e+08
# 137533                    0.4570                2.380509e+08
# 137534                    0.4570                2.380509e+08
# 137535                    0.4570                2.380509e+08
# 137671                    0.4140                2.420595e+08
#
#         Compound_dAtomic_Mass_Micro  Compound_S(2n)  Compound_dS(2n)  \
# 16                          0.00012        2025.412          292.506
# 17                          0.00012        2025.412          292.506
# 18                          0.00012        2025.412          292.506
# 166                         0.00023        8481.790            0.000
# 167                         0.00023        8481.790            0.000
# ...                             ...             ...              ...
# 137532                      1.22100       12066.160           50.420
# 137533                      1.22100       12066.160           50.420
# 137534                      1.22100       12066.160           50.420
# 137535                      1.22100       12066.160           50.420
# 137671                      1.20000       12184.730           13.790
#
#         Compound_S(2p)  Compound_dS(2p)  Compound_S(n)  Compound_dS(n)  \
# 16        13771.880283       158.524008        2224.57             0.0
# 17        13771.880283       158.524008        2224.57             0.0
# 18        13771.880283       158.524008        2224.57             0.0
# 166       13771.880283       158.524008        6257.23             0.0
# 167       13771.880283       158.524008        6257.23             0.0
# ...                ...              ...            ...             ...
# 137532    12457.230000        14.020000        5488.32             0.2
# 137533    12457.230000        14.020000        5488.32             0.2
# 137534    12457.230000        14.020000        5488.32             0.2
# 137535    12457.230000        14.020000        5488.32             0.2
# 137671    11426.140000        17.020000        5537.64             0.1
#
#         Compound_S(p)  Compound_dS(p)
# 16           2224.570            0.00
# 17           2224.570            0.00
# 18           2224.570            0.00
# 166          1112.285            0.00
# 167          1112.285            0.00
# ...               ...             ...
# 137532       5224.510            0.56
# 137533       5224.510            0.56
# 137534       5224.510            0.56
# 137535       5224.510            0.56
# 137671       4776.070            0.19
#
# [78609 rows x 66 columns]

# %%
# endf_all = endf_utils.load_endf("./ENDF/Chlorine_Data/endf_Cl_np_all.csv")

# %%
# endf_u = endf_utils.load_endf("./ENDF/Uranium_Data/endf_U_tot.csv", mev_to_ev=True)

# %% [markdown]
# # Exploratory Data Analysis
#
# Let us study the dataset and analyze the distributions.

# %%
sns.set(font_scale = 2)

# %%
figure_dir = "./Figures/EXFOR_P/"

# %%
plot_utils.kdeplot(df.Target_Mass_Number, xlabel='Atomic Mass (A)', title='EXFOR Atomic Mass Distribution', 
                   save=True, path=figure_dir+'EXFOR_Atomic_Mass_Dist.png')

# %% [markdown]
# # Institute, Reaction Types, and Isotopes
#
# We can see by the distributions that the majority of the measurments have been made at Oak Ridge National Laboratory's LINAC facility.
#
# The majority of the measurments in the EXFOR dataset are (n,tot) followed by (n,g) and (n,f). Other reaction types that have been measured are Inelastic and Elastic Scattering and in lesser extent (n,p) and (n,a) reaciton types.
#
# As for Isotopes, Fe-56, Pu-239, U-235, 238U 233U Al-27 Np-237, 91Zr cover the majority of the measruments here.

# %%
cat_cols_plot = ["Institute", "Out", "Target_Element_w_A"]
plot_utils.cat_plot(cat_cols_plot, df, 'Reference', save=True, path=figure_dir + "EXFOR")

# %% [markdown]
# # Energy Distribution (thermal or fast measruments?), Year

# %%
sns.set(font_scale=1)

# %%
campaigns = df[['Year', 'Title']].groupby(['Year']).agg(['count']).reset_index().sort_values(by="Year")
campaigns.columns = ["Year", "Counts"]

# %%
campaigns.plot(x="Year", y="Counts", kind='bar', figsize=(18,10))
plt.savefig(figure_dir + 'EXFOR_experiments_year.png', bbox_inches='tight')

# %%
sns.set(font_scale=2)

# %%
energy = ((df.sort_values(by="Energy").Energy) * 1E-6)
energy_l15 = energy[energy < 200]

# %%
plot_utils.kdeplot(energy_l15, xlabel='Energy [MeV]', title='EXFOR Proton Energy Distribution', 
                   save=True, path=figure_dir+'EXFOR_Energy_Dist.png')

# %% [markdown]
# # Copper Energy Distribution

# %%
arsenic = exfor_utils.load_exfor_samples(df, 33, 75, "9001", one_hot=False)
arsenic.shape
# Out:
# Extracting samples from dataframe.
# EXFOR extracted DataFrame has shape:  (41, 66)
# (41, 66)

# %%
copper = exfor_utils.load_exfor_samples(df, 29, 65, "4", one_hot=False)
# Get rid of last point for plotting
# copper = copper.iloc[:-1]
copper.shape
# Out:
# Extracting samples from dataframe.
# EXFOR extracted DataFrame has shape:  (919, 66)
# (919, 66)

# %%
arsenic
# Out:
#       Target_Meta_State    MT       Energy       dEnergy      Data     dData  \
# 66951               All  9001  400000000.0  5.000000e+05  0.000040  0.000001
# 66952               All  9001  400000000.0  5.000000e+05  0.000040  0.000005
# 66988               All  9001  540000000.0  7.891546e+06  0.001420  0.000227
# 66986               All  9001  540000000.0  7.891546e+06  0.005460  0.000872
# 66984               All  9001  540000000.0  7.891546e+06  0.002130  0.000340
# 66981               All  9001  540000000.0  7.891546e+06  0.001350  0.000215
# 66979               All  9001  540000000.0  7.891546e+06  0.000360  0.000057
# 66977               All  9001  540000000.0  7.891546e+06  0.002450  0.000391
# 66974               All  9001  540000000.0  7.891546e+06  0.000243  0.000039
# 66972               All  9001  540000000.0  7.891546e+06  0.001430  0.000228
# 66970               All  9001  540000000.0  7.891546e+06  0.006710  0.001071
# 66967               All  9001  540000000.0  7.891546e+06  0.001150  0.000184
# 66964               All  9001  540000000.0  7.891546e+06  0.003350  0.000535
# 66991               All  9001  540000000.0  7.891546e+06  0.000160  0.000026
# 66962               All  9001  540000000.0  7.891546e+06  0.012900  0.002059
# 66954               All  9001  540000000.0  7.891546e+06  0.016300  0.002602
# 66960               All  9001  540000000.0  7.891546e+06  0.002360  0.000377
# 66957               All  9001  540000000.0  7.891546e+06  0.024400  0.003895
# 66965               All  9001  593000000.0  8.666087e+06  0.007100  0.001133
# 66989               All  9001  593000000.0  8.666087e+06  0.000230  0.000070
# 66953               All  9001  593000000.0  8.666087e+06  0.015200  0.002426
# 66987               All  9001  593000000.0  8.666087e+06  0.001770  0.000283
# 66985               All  9001  593000000.0  8.666087e+06  0.006000  0.000958
# 66955               All  9001  593000000.0  8.666087e+06  0.004450  0.000710
# 66983               All  9001  593000000.0  8.666087e+06  0.002290  0.000366
# 66982               All  9001  593000000.0  8.666087e+06  0.000040  0.000015
#       EXFOR_Status Frame                Reaction_Notation  \
# 66951        Other     L  33-AS-75(P,X)11-NA-24-G,CUM,SIG
# 66952        Other     L    33-AS-75(P,X)11-NA-22,CUM,SIG
# 66988        Other     L     33-AS-75(P,X)23-V-48,CUM,SIG
# 66986        Other     L    33-AS-75(P,X)24-CR-51,CUM,SIG
# 66984        Other     L    33-AS-75(P,X)25-MN-56,CUM,SIG
# 66981        Other     L    33-AS-75(P,X)26-FE-59,CUM,SIG
# 66979        Other     L    33-AS-75(P,X)27-CO-55,CUM,SIG
# 66977        Other     L    33-AS-75(P,X)27-CO-56,CUM,SIG
# 66974        Other     L    33-AS-75(P,X)28-NI-57,CUM,SIG
# 66972        Other     L    33-AS-75(P,X)29-CU-60,CUM,SIG
# 66970        Other     L    33-AS-75(P,X)29-CU-61,CUM,SIG
# 66967        Other     L    33-AS-75(P,X)30-ZN-62,CUM,SIG
# 66964        Other     L    33-AS-75(P,X)31-GA-65,CUM,SIG
# 66991        Other     L     33-AS-75(P,X)19-K-43,CUM,SIG
# 66962        Other     L    33-AS-75(P,X)31-GA-66,CUM,SIG
# 66954        Other     L    33-AS-75(P,X)33-AS-71,CUM,SIG
# 66960        Other     L    33-AS-75(P,X)32-GE-67,CUM,SIG
# 66957        Other     L    33-AS-75(P,X)32-GE-69,CUM,SIG
# 66965        Other     L    33-AS-75(P,X)30-ZN-63,CUM,SIG
# 66989        Other     L    33-AS-75(P,X)21-SC-43,CUM,SIG
# 66953        Other     L    33-AS-75(P,X)33-AS-71,CUM,SIG
# 66987        Other     L     33-AS-75(P,X)23-V-48,CUM,SIG
# 66985        Other     L    33-AS-75(P,X)24-CR-51,CUM,SIG
# 66955        Other     L    33-AS-75(P,X)33-AS-70,CUM,SIG
# 66983        Other     L    33-AS-75(P,X)25-MN-56,CUM,SIG
# 66982        Other     L    33-AS-75(P,X)26-FE-52,CUM,SIG
# 66956        Other     L    33-AS-75(P,X)32-GE-69,CUM,SIG
# 66980        Other     L    33-AS-75(P,X)26-FE-59,CUM,SIG
# 66978        Other     L    33-AS-75(P,X)27-CO-55,CUM,SIG
# 66958        Other     L    33-AS-75(P,X)32-GE-68,CUM,SIG
# 66976        Other     L    33-AS-75(P,X)27-CO-56,CUM,SIG
# 66975        Other     L  33-AS-75(P,X)27-CO-62-M,CUM,SIG
# 66959        Other     L    33-AS-75(P,X)32-GE-67,CUM,SIG
# 66973        Other     L    33-AS-75(P,X)28-NI-57,CUM,SIG
# 66990        Other     L     33-AS-75(P,X)19-K-43,CUM,SIG
# 66961        Other     L    33-AS-75(P,X)31-GA-66,CUM,SIG
# 66969        Other     L    33-AS-75(P,X)29-CU-61,CUM,SIG
# 66968        Other     L    33-AS-75(P,X)29-CU-67,CUM,SIG
# 66966        Other     L    33-AS-75(P,X)30-ZN-62,CUM,SIG
# 66963        Other     L    33-AS-75(P,X)31-GA-65,CUM,SIG
# 66971        Other     L    33-AS-75(P,X)29-CU-60,CUM,SIG
#
#                                                    Title  Year  Institute  \
# 66951  Systematics of Na-24 and Na-22 Production with...  1967  (1USACAR)
# 66952  Systematics of Na-24 and Na-22 Production with...  1967  (1USACAR)
# 66988  Cross sections for reactions with 593 MeV- and...  1982  (2SWTPSI)
# 
# 66988                   0.012               -864.714                   0.882
# 66986                   0.012               -864.714                   0.882
# 66984                   0.012               -864.714                   0.882
# 66981                   0.012               -864.714                   0.882
# 66979                   0.012               -864.714                   0.882
# 66977                   0.012               -864.714                   0.882
# 66974                   0.012               -864.714                   0.882
# 66972                   0.012               -864.714                   0.882
# 66970                   0.012               -864.714                   0.882
# 66967                   0.012               -864.714                   0.882
# 66964                   0.012               -864.714                   0.882
# 66991                   0.012               -864.714                   0.882
# 66962                   0.012               -864.714                   0.882
# 66954                   0.012               -864.714                   0.882
# 66960                   0.012               -864.714                   0.882
# 66957                   0.012               -864.714                   0.882
# 66965                   0.012               -864.714                   0.882
# 66989                   0.012               -864.714                   0.882
# 66953                   0.012               -864.714                   0.882
# 66987                   0.012               -864.714                   0.882
# 66985                   0.012               -864.714                   0.882
# 66955                   0.012               -864.714                   0.882
# 66983                   0.012               -864.714                   0.882
# 66982                   0.012               -864.714                   0.882
# 66956                   0.012               -864.714                   0.882
# 66980                   0.012               -864.714                   0.882
# 66978                   0.012               -864.714                   0.882
# 66958                   0.012               -864.714                   0.882
# 66976                   0.012               -864.714                   0.882
# 66975                   0.012               -864.714                   0.882
# 66959                   0.012               -864.714                   0.882
# 66973                   0.012               -864.714                   0.882
# 66990                   0.012               -864.714                   0.882
# 66961                   0.012               -864.714                   0.882
# 66969                   0.012               -864.714                   0.882
# 66968                   0.012               -864.714                   0.882
# 66966                   0.012               -864.714                   0.882
# 66963                   0.012               -864.714                   0.882
# 66971                   0.012               -864.714                   0.882
#
#        Target_Atomic_Mass_Micro  Target_dAtomic_Mass_Micro  Target_S(2n)  \
# 66951              7.492159e+07                      0.948      18224.08
# 66952              7.492159e+07                      0.948      18224.08
# 66988              7.492159e+07                      0.948      18224.08
# 66986              7.492159e+07                      0.948      18224.08
# 66984              7.492159e+07                      0.948      18224.08
# 66981              7.492159e+07                      0.948      18224.08
# 66979              7.492159e+07                      0.948      18224.08
# 66977              7.492159e+07                      0.948      18224.08
# 66974              7.492159e+07                      0.948      18224.08
# 66972              7.492159e+07                      0.948      18224.08
# 66970              7.492159e+07                      0.948      18224.08
# 66967              7.492159e+07                      0.948      18224.08
# 66964              7.492159e+07                      0.948      18224.08
# 66991              7.492159e+07                      0.948      18224.08
# 66962              7.492159e+07                      0.948      18224.08
# 66954              7.492159e+07                      0.948      18224.08
# 66960              7.492159e+07                      0.948      18224.08
# 66957              7.492159e+07                      0.948      18224.08
# 66965              7.492159e+07                      0.948      18224.08
# 66989              7.492159e+07                      0.948      18224.08
# 66953              7.492159e+07                      0.948      18224.08
# 66987              7.492159e+07                      0.948      18224.08
# 66985              7.492159e+07                      0.948      18224.08
# 66955              7.492159e+07                      0.948      18224.08
# 66983              7.492159e+07                      0.948      18224.08
# 66982              7.492159e+07                      0.948      18224.08
# 66956              7.492159e+07                      0.948      18224.08
# 66980              7.492159e+07                      0.948      18224.08
# 66978              7.492159e+07                      0.948      18224.08
# 66958              7.492159e+07                      0.948      18224.08
# 66976              7.492159e+07                      0.948      18224.08
# 66981      6900.72          0.88                 43                    76
# 66979      6900.72          0.88                 43                    76
# 66977      6900.72          0.88                 43                    76
# 66974      6900.72          0.88                 43                    76
# 66972      6900.72          0.88                 43                    76
# 66970      6900.72          0.88                 43                    76
# 66967      6900.72          0.88                 43                    76
# 66964      6900.72          0.88                 43                    76
# 66991      6900.72          0.88                 43                    76
# 66962      6900.72          0.88                 43                    76
# 66954      6900.72          0.88                 43                    76
# 66960      6900.72          0.88                 43                    76
# 66957      6900.72          0.88                 43                    76
# 66965      6900.72          0.88                 43                    76
# 66989      6900.72          0.88                 43                    76
# 66953      6900.72          0.88                 43                    76
# 66987      6900.72          0.88                 43                    76
# 66985      6900.72          0.88                 43                    76
# 66955      6900.72          0.88                 43                    76
# 66983      6900.72          0.88                 43                    76
# 66982      6900.72          0.88                 43                    76
# 66956      6900.72          0.88                 43                    76
# 66980      6900.72          0.88                 43                    76
# 66978      6900.72          0.88                 43                    76
# 66958      6900.72          0.88                 43                    76
# 66976      6900.72          0.88                 43                    76
# 66975      6900.72          0.88                 43                    76
# 66959      6900.72          0.88                 43                    76
# 66973      6900.72          0.88                 43                    76
# 66990      6900.72          0.88                 43                    76
# 66961      6900.72          0.88                 43                    76
# 66969      6900.72          0.88                 43                    76
# 66968      6900.72          0.88                 43                    76
# 66966      6900.72          0.88                 43                    76
# 66963      6900.72          0.88                 43                    76
# 66971      6900.72          0.88                 43                    76
#
#        Compound_Protons Compound_EL Compound_Origin  Compound_Mass_Excess  \
# 66951                33          As              -n            -72291.377
# 66952                33          As              -n            -72291.377
# 66988                33          As              -n            -72291.377
# 66986                33          As              -n            -72291.377
# 66984                33          As              -n            -72291.377
# 66981                33          As              -n            -72291.377
# 66979                33          As              -n            -72291.377
# 66977                33          As              -n            -72291.377
# 66974                33          As              -n            -72291.377
# 66972                33          As              -n            -72291.377
# 66970                33          As              -n            -72291.377
# 66967                33          As              -n            -72291.377
# 66964                33          As              -n            -72291.377
# 66991                33          As              -n            -72291.377
# 66962                33          As              -n            -72291.377
# 66954                33          As              -n            -72291.377
# 66960                33          As              -n            -72291.377
# 66957                33          As              -n            -72291.377
# 66965                33          As              -n            -72291.377
# 66989                33          As              -n            -72291.377
# 66953                33          As              -n            -72291.377
# 66987                33          As              -n            -72291.377
# 66985                33          As              -n            -72291.377
# 66955                33          As              -n            -72291.377
# 66983                33          As              -n            -72291.377
# 66982                33          As              -n            -72291.377
# 66956                33          As              -n            -72291.377
# 66980                33          As              -n            -72291.377
# 66978                33          As              -n            -72291.377
# 66958                33          As              -n            -72291.377
# 66976                33          As              -n            -72291.377
# 66975                33          As              -n            -72291.377
# 66959                33          As              -n            -72291.377
# 66973                33          As              -n            -72291.377
# 66990                33          As              -n            -72291.377
# 66961                33          As              -n            -72291.377
# 66969                33          As              -n            -72291.377
# 66968                33          As              -n            -72291.377
# 66966                33          As              -n            -72291.377
# 66963                33          As              -n            -72291.377
# 66971                33          As              -n            -72291.377
#
#        Compound_dMass_Excess  Compound_Binding_Energy  \
# [33-AS-75(P,X)11-NA-24-G,CUM,SIG, 33-AS-75(P,X)11-NA-22,CUM,SIG, 33-AS-75(P,X)23-V-48,CUM,SIG, 33-AS-75(P,X)24-CR-51,CUM,SIG, 33-AS-75(P,X)25-MN-56,CUM,SIG, ..., 33-AS-75(P,X)33-AS-70,CUM,SIG, 33-AS-75(P,X)26-FE-52,CUM,SIG, 33-AS-75(P,X)32-GE-68,CUM,SIG, 33-AS-75(P,X)27-CO-62-M,CUM,SIG, 33-AS-75(P,X)29-CU-67,CUM,SIG]
# Length: 25
# Categories (25, object): [33-AS-75(P,X)11-NA-24-G,CUM,SIG, 33-AS-75(P,X)11-NA-22,CUM,SIG, 33-AS-75(P,X)23-V-48,CUM,SIG, 33-AS-75(P,X)24-CR-51,CUM,SIG, ..., 33-AS-75(P,X)26-FE-52,CUM,SIG, 33-AS-75(P,X)32-GE-68,CUM,SIG, 33-AS-75(P,X)27-CO-62-M,CUM,SIG, 33-AS-75(P,X)29-CU-67,CUM,SIG]

# %%
copper.Reaction_Notation.unique()
# Out:
# [29-CU-65(P,N)30-ZN-65,,SIG, 29-CU-65(P,N)30-ZN-65,,SIG,,,EXP]
# Categories (2, object): [29-CU-65(P,N)30-ZN-65,,SIG, 29-CU-65(P,N)30-ZN-65,,SIG,,,EXP]

# %%
copper.Reaction_Notation.unique()
# Out:
# [29-CU-65(P,N)30-ZN-65,,SIG, 29-CU-65(P,N)30-ZN-65,,SIG,,,EXP]
# Categories (2, object): [29-CU-65(P,N)30-ZN-65,,SIG, 29-CU-65(P,N)30-ZN-65,,SIG,,,EXP]

# %%
plt.figure(figsize=(15,10))
plt.scatter(copper.Energy, copper.Data)
# plt.xlim(0, 2.5E7)
# plt.yscale('log')
plt.xscale('log')

# %%
energy_cu = ((copper.sort_values(by="Energy").Energy) * 1E-6)

# %%
plot_utils.kdeplot([energy_l15, energy_cu], labels=['EXFOR', 'Copper'], 
                   save=True,
                   xlabel='Energy [MeV]', path=figure_dir + 'EXFOR_Cu_Energy_Dist.png')

# %%
sns.set(font_scale=1)

# %%
from Utilities import EXFOR_utilities as exfor_utils
from Utilities import ENDF_utilities as endf_utils
from Utilities import Plotting_utilities as plot_utils
importlib.reload(exfor_utils)
importlib.reload(endf_utils)
importlib.reload(plot_utils)
print("Finish importing scripts.")
# Out:
# Finish importing scripts.

# %%
exfor_utils.plot_exfor_w_references(df, 29, 65, "4", nat_iso="I", error=False, save=True, 
                                    interpolate=False, legend=True, alpha=0.7, one_hot=False, 
                                    log_e=False, path=figure_dir, ref=False)

# # exfor_utils.plot_exfor_w_references(df_plotting, 17, 35, "103", nat_iso="I", new_data=new_data_nolog, endf=endf_cl_nolog, error=True, 
# #                                     save=False, interpolate=False, legend=False, alpha=0.7, one_hot=False, 
# #                                     log_e=False, path=figure_dir, ref=True)
# Out:
# Extracting samples from dataframe.
# EXFOR extracted DataFrame has shape:  (919, 88)

# %%
# exfor_utils.plot_exfor_w_references(df, 92, 235, "MT_1", nat_iso="I", endf=endf_u, error=True, 
#                                     save=False, interpolate=False, legend=False, alpha=0.7, one_hot=True, 
#                                     log_e=True, path=figure_dir, ref=False)

# # exfor_utils.plot_exfor_w_references(df_plotting, 92, 235, "1", nat_iso="I", endf=endf_u_nolog, error=True, 
# #                                     save=False, interpolate=False, legend=False, alpha=0.7, one_hot=False, 
# #                                     log_e=False, path=figure_dir, ref=True)

# %% [markdown]
# # Numerical Features
#
# Lets follow up with the Chlorine-35 (n,p) example.

# %%
uranium = df[(df["Target_Protons"] == 92) & (df["MT"] == 1) & (df["Target_Mass_Number"] == 235)].sort_values(
    by='Energy', ascending=False)

# %%
chlorine = df[(df["Target_Protons"] == 17) & (df["MT"] == 103) & (df["Target_Mass_Number"] == 35)].sort_values(by='Energy', ascending=False)

# %%
chlorine.describe()
# Out:
#              Energy        dEnergy        Data       dData  ELV/HL  dELV/HL  \
# count  2.160000e+02     216.000000  216.000000  216.000000   216.0    216.0
# mean   2.746206e+05    3331.131388    0.168940    0.010491     0.0      0.0
# std    1.958895e+06   23749.179229    0.812348    0.053155     0.0      0.0
# min    2.530000e-02       0.000261    0.000048    0.000048     0.0      0.0
# 25%    1.845750e+01       0.261210    0.002100    0.000380     0.0      0.0
# 50%    3.511000e+02       6.011867    0.010100    0.001350     0.0      0.0
# 75%    2.382000e+03      21.926103    0.073650    0.003500     0.0      0.0
# max    1.470000e+07  200000.000000    8.730000    0.570000     0.0      0.0
#
#        Target_Protons         Year          Date  Target_Neutrons  \
# count           216.0   216.000000  2.160000e+02            216.0
# mean             17.0  1984.662037  1.993674e+07             18.0
# std               0.0    12.371071  4.075400e+04              0.0
# min              17.0  1961.000000  1.992020e+07             18.0
# 25%              17.0  1991.000000  1.992020e+07             18.0
# 50%              17.0  1991.000000  1.992020e+07             18.0
# 75%              17.0  1991.000000  1.992020e+07             18.0
# max              17.0  2006.000000  2.017040e+07             18.0
#
#        Target_Mass_Number  Target_Radius  Target_Neut_Rad_Ratio  \
# count               216.0   2.160000e+02           2.160000e+02
# mean                 35.0   4.088833e+00           1.956549e-01
# std                   0.0   1.780483e-15           5.564010e-17
# min                  35.0   4.088833e+00           1.956549e-01
# 25%                  35.0   4.088833e+00           1.956549e-01
# 50%                  35.0   4.088833e+00           1.956549e-01
# 75%                  35.0   4.088833e+00           1.956549e-01
# max                  35.0   4.088833e+00           1.956549e-01
#
#        Target_Mass_Excess  Target_dMass_Excess  Target_Binding_Energy  \
# count          216.000000           216.000000             216.000000
# mean        -28940.556340             0.901059            8518.131541
# std           1072.459992            12.728416              31.546375
# min         -29013.528000             0.035000            8056.642875
# 25%         -29013.528000             0.035000            8520.278000
# 50%         -29013.528000             0.035000            8520.278000
# 75%         -29013.528000             0.035000            8520.278000
# max         -13251.649500           187.103750            8520.278000
#
#        Target_dBinding_Energy  Target_B_Decay_Energy  Target_dB_Decay_Energy  \
# count              216.000000             216.000000              216.000000
# mean                 0.021770           -5916.991437                1.645520
# std                  0.305251             723.847195               14.204891
# min                  0.001000           -5966.243000                0.679000
# 25%                  0.001000           -5966.243000                0.679000
# 50%                  0.001000           -5966.243000                0.679000
# 75%                  0.001000           -5966.243000                0.679000
# max                  4.487250            4672.094682              209.447409
#
#        Target_Atomic_Mass_Micro  Target_dAtomic_Mass_Micro  Target_S(2n)  \
# count              2.160000e+02                 216.000000    216.000000
# mean               3.497109e+07                   0.967523  24119.670213
# std                3.294205e+04                  13.661145    487.347356
# min                3.496885e+07                   0.038000  16990.315909
# 25%                3.496885e+07                   0.038000  24152.830000
# 50%                3.496885e+07                   0.038000  24152.830000
# 75%                3.496885e+07                   0.038000  24152.830000
# max                3.545300e+07                 200.815000  24152.830000
#
#        Target_dS(2n)  Target_S(2p)  Target_dS(2p)   Target_S(n)  Target_dS(n)  \
# count     216.000000    216.000000     216.000000    216.000000    216.000000
# mean        1.485549  17280.916168       2.250758  12626.248752      1.180578
# std        16.101220    393.821631      17.059583    272.058672     16.616031
# min         0.390000  17254.120000       1.090000   8646.330435      0.050000
# 25%         0.390000  17254.120000       1.090000  12644.760000      0.050000
# 50%         0.390000  17254.120000       1.090000  12644.760000      0.050000
# 75%         0.390000  17254.120000       1.090000  12644.760000      0.050000
# max       237.028636  23042.092273     251.813636  12644.760000    244.254783
#
#        Target_S(p)  Target_dS(p)  Compound_Neutrons  Compound_Mass_Number  \
# count   216.000000    216.000000              216.0                 216.0
# mean   6386.111274      1.187365               19.0                  36.0
# std     224.881885     16.862755                0.0                   0.0
# min    6370.810000      0.040000               19.0                  36.0
# 25%    6370.810000      0.040000               19.0                  36.0
# 50%    6370.810000      0.040000               19.0                  36.0
# 75%    6370.810000      0.040000               19.0                  36.0
# max    9675.885217    247.870870               19.0                  36.0
#
#        Compound_Protons  Compound_Mass_Excess  Compound_dMass_Excess  \
# count             216.0               216.000           2.160000e+02
# mean               17.0            -29522.005           3.600000e-02
# std                 0.0                 0.000           1.391002e-17
# min                17.0            -29522.005           3.600000e-02
# 25%                17.0            -29522.005           3.600000e-02
# 50%                17.0            -29522.005           3.600000e-02
# 75%                17.0            -29522.005           3.600000e-02
# max                17.0            -29522.005           3.600000e-02
#
#        Compound_Binding_Energy  Compound_dBinding_Energy  \
# count             2.160000e+02              2.160000e+02
# mean              8.521931e+03              1.000000e-03
# std               3.646429e-12              4.346883e-19
# min               8.521931e+03              1.000000e-03
# 25%               8.521931e+03              1.000000e-03
# 50%               8.521931e+03              1.000000e-03
# 75%               8.521931e+03              1.000000e-03
# max               8.521931e+03              1.000000e-03
#
#        Compound_B_Decay_Energy  Compound_dB_Decay_Energy  \
# count                  216.000              2.160000e+02
# mean                   709.535              4.500000e-02
# std                      0.000              6.955012e-18
# min                    709.535              4.500000e-02
# 25%                    709.535              4.500000e-02
# 50%                    709.535              4.500000e-02
# 75%                    709.535              4.500000e-02
# max                    709.535              4.500000e-02
#
#        Compound_Atomic_Mass_Micro  Compound_dAtomic_Mass_Micro  \
# count                2.160000e+02                 2.160000e+02
# mean                 3.596831e+07                 3.800000e-02
# std                  1.493577e-08                 6.955012e-18
# min                  3.596831e+07                 3.800000e-02
# 25%                  3.596831e+07                 3.800000e-02
# 50%                  3.596831e+07                 3.800000e-02
# 75%                  3.596831e+07                 3.800000e-02
# max                  3.596831e+07                 3.800000e-02
#
#        Compound_S(2n)  Compound_dS(2n)  Compound_S(2p)  Compound_dS(2p)  \
# count    2.160000e+02           216.00          216.00     2.160000e+02
# mean     2.122456e+04             0.05        19551.25     8.100000e-01
# std      3.646429e-12             0.00            0.00     3.338406e-16
# min      2.122456e+04             0.05        19551.25     8.100000e-01
# 25%      2.122456e+04             0.05        19551.25     8.100000e-01
# 50%      2.122456e+04             0.05        19551.25     8.100000e-01
# 75%      2.122456e+04             0.05        19551.25     8.100000e-01
# max      2.122456e+04             0.05        19551.25     8.100000e-01
#
#        Compound_S(n)  Compound_dS(n)  Compound_S(p)  Compound_dS(p)
# count   2.160000e+02           216.0   2.160000e+02    2.160000e+02
# mean    8.579790e+03             0.0   7.964770e+03    3.000000e-02
# std     3.646429e-12             0.0   2.734822e-12    1.043252e-17
# min     8.579790e+03             0.0   7.964770e+03    3.000000e-02
# 25%     8.579790e+03             0.0   7.964770e+03    3.000000e-02
# 50%     8.579790e+03             0.0   7.964770e+03    3.000000e-02
# 75%     8.579790e+03             0.0   7.964770e+03    3.000000e-02
# max     8.579790e+03             0.0   7.964770e+03    3.000000e-02

# %% [markdown]
# We can explor correlation among features but as we know beforehand, cross section do not behave linearly. Let us use the chlorine 35 n,p cross sections as an example.

# %%
pd.DataFrame(chlorine.corr()).sort_values(by='Data', ascending=False).head()
# Out:
#                           Energy   dEnergy      Data     dData  ELV/HL  \
# Data                    0.000392 -0.001125  1.000000  0.993708     NaN
# dData                   0.039680  0.037766  0.993708  1.000000     NaN
# Year                   -0.170847 -0.172947  0.090526  0.069616     NaN
# Target_S(p)            -0.009583 -0.009588  0.016919  0.012228     NaN
# Target_dBinding_Energy -0.009583 -0.009588  0.016919  0.012228     NaN
#
#                         dELV/HL  Target_Protons      Year      Date  \
# Data                        NaN             NaN  0.090526 -0.026421
# dData                       NaN             NaN  0.069616 -0.000872
# Year                        NaN             NaN  1.000000 -0.534500
# Target_S(p)                 NaN             NaN  0.117906  0.308570
# Target_dBinding_Energy      NaN             NaN  0.117906  0.308570
#
#                         Target_Neutrons  Target_Mass_Number  Target_Radius  \
# Data                                NaN                 NaN   1.496698e-17
# dData                               NaN                 NaN  -2.653207e-16
# Year                                NaN                 NaN  -6.823022e-15
# Target_S(p)                         NaN                 NaN   1.447477e-13
# Target_dBinding_Energy              NaN                 NaN  -1.728254e-16
#
#                         Target_Neut_Rad_Ratio  Target_Mass_Excess  \
# Data                             7.972726e-18            0.016919
# dData                            2.538979e-16            0.012228
# Year                             6.823022e-15            0.117906
# Target_S(p)                     -1.439605e-13            1.000000
# Target_dBinding_Energy           1.543084e-16            1.000000
#
#                         Target_dMass_Excess  Target_Binding_Energy  \
# Data                               0.016919              -0.016919
# dData                              0.012228              -0.012228
# Year                               0.117906              -0.117906
# Target_S(p)                        1.000000              -1.000000
# Target_dBinding_Energy             1.000000              -1.000000
#
#                         Target_dBinding_Energy  Target_B_Decay_Energy  \
# Data                                  0.016919               0.016919
# dData                                 0.012228               0.012228
# Year                                  0.117906               0.117906
# Target_S(p)                           1.000000               1.000000
# Target_dBinding_Energy                1.000000               1.000000
#
#                         Target_dB_Decay_Energy  Target_Atomic_Mass_Micro  \
# Data                                  0.016919                  0.016919
# dData                                 0.012228                  0.012228
# Year                                  0.117906                  0.117906
# Target_S(p)                           1.000000                  1.000000
# Target_dBinding_Energy                1.000000                  1.000000
#
#                         Target_dAtomic_Mass_Micro  Target_S(2n)  \
# Data                                     0.016919     -0.016919
# dData                                    0.012228     -0.012228
# Year                                     0.117906     -0.117906
# Target_S(p)                              1.000000     -1.000000
# Target_dBinding_Energy                   1.000000     -1.000000
#
#                         Target_dS(2n)  Target_S(2p)  Target_dS(2p)  \
# Data                         0.016919      0.016919       0.016919
# dData                        0.012228      0.012228       0.012228
# Year                         0.117906      0.117906       0.117906
# Target_S(p)                  1.000000      1.000000       1.000000
# Target_dBinding_Energy       1.000000      1.000000       1.000000
#
#                         Target_S(n)  Target_dS(n)  Target_S(p)  Target_dS(p)  \
# Data                      -0.016919      0.016919     0.016919      0.016919
# dData                     -0.012228      0.012228     0.012228      0.012228
# Year                      -0.117906      0.117906     0.117906      0.117906
# Target_S(p)               -1.000000      1.000000     1.000000      1.000000
# Target_dBinding_Energy    -1.000000      1.000000     1.000000      1.000000
#
#                         Compound_Neutrons  Compound_Mass_Number  \
# Data                                  NaN                   NaN
# dData                                 NaN                   NaN
# Year                                  NaN                   NaN
# Target_S(p)                           NaN                   NaN
# Target_dBinding_Energy                NaN                   NaN
#
#                         Compound_Protons  Compound_Mass_Excess  \
# Data                                 NaN          2.293246e-17
# dData                                NaN         -2.958992e-16
# Year                                 NaN         -7.662254e-15
# Target_S(p)                          NaN          1.440961e-13
# Target_dBinding_Energy               NaN          1.382603e-16
#
#                         Compound_dMass_Excess  Compound_Binding_Energy  \
# Data                             5.129926e-17            -3.231052e-17
# dData                            2.336868e-16            -2.757142e-16
# Year                             6.033320e-15            -5.970144e-15
# Target_S(p)                     -1.445214e-13             1.441558e-13
# Target_dBinding_Energy          -2.400352e-16             1.932915e-16
#
#                         Compound_dBinding_Energy  Compound_B_Decay_Energy  \
# Data                               -5.707747e-18            -5.707747e-18
# dData                              -2.945989e-16            -2.945989e-16
# Year                               -6.823022e-15            -6.823022e-15
# Target_S(p)                         1.441196e-13             1.441196e-13
# Target_dBinding_Energy             -3.150462e-16            -3.150462e-16
#
#                         Compound_dB_Decay_Energy  Compound_Atomic_Mass_Micro  \
# Data                               -6.167538e-17               -2.293246e-17
# dData                               2.980315e-16                2.958992e-16
# Year                                6.823022e-15                7.662254e-15
# Target_S(p)                        -1.443386e-13               -1.440961e-13
# Target_dBinding_Energy              1.350198e-16               -1.382603e-16
#
#                         Compound_dAtomic_Mass_Micro  Compound_S(2n)  \
# Data                                  -1.600121e-17    6.167538e-17
# dData                                 -2.761311e-16   -2.980315e-16
# Year                                  -7.229779e-15   -6.823022e-15
# Target_S(p)                            1.445825e-13    1.443386e-13
# Target_dBinding_Energy                -2.160317e-16   -1.350198e-16
#
#                         Compound_dS(2n)  Compound_S(2p)  Compound_dS(2p)  \
# Data                      -5.707747e-18             NaN     3.230162e-17
# dData                     -2.945989e-16             NaN    -3.117619e-16
# Year                      -6.823022e-15             NaN    -6.117976e-15
# Target_S(p)                1.441196e-13             NaN     1.444724e-13
# Target_dBinding_Energy    -3.150462e-16             NaN    -5.760846e-17
#
#                         Compound_S(n)  Compound_dS(n)  Compound_S(p)  \
# Data                    -1.600121e-17             NaN   6.167538e-17
# dData                   -2.761311e-16             NaN  -2.980315e-16
# Year                    -7.229779e-15             NaN  -6.823022e-15
# Target_S(p)              1.445825e-13             NaN   1.443386e-13
# Target_dBinding_Energy  -2.160317e-16             NaN  -1.350198e-16
#
#                         Compound_dS(p)
# Data                     -1.600121e-17
# dData                    -2.761311e-16
# Year                     -7.229779e-15
# Target_S(p)               1.445825e-13
# Target_dBinding_Energy   -2.160317e-16

# %% [markdown]
# <b>P-value</b>:
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(chlorine['Energy'], chlorine['Data'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.00039191327732860607  with a P-value of P = 0.9954309362611046

# %% [markdown]
# The energy is weakley linearly correlated. The p-value results in 1% confidence that this correlation is significant. We therefore expect that a linear model will work poorly in this data. As a nuclear engineer, we know that there are depedences on Energy depending on the region. One solution could be to split the data into the appropiate energy ranges but that would defeat the purpose of this project.

# %%
num_columns = []
for col in list(df.columns):
    if col not in str_cols:
        num_columns.append(col)

# %%
fig, ax = plt.subplots(figsize=(25,30))
to_plot[num_columns].hist(ax=ax)
plt.savefig(figure_dir + 'example.svg')  
plt.close(fig)
# Out:
# C:\Users\Pedro\Anaconda3\envs\data_mining_gpu\lib\site-packages\ipykernel_launcher.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared

# %% [markdown]
# We can see that several features are extremeley negatively skewed. This introduces problems to almost all ML algorithms as we shall demonstrate in the next notebook.

# %%
from scipy.stats import skew

# %% [markdown]
# - skewness = 0 : normally distributed.
# - skewness > 0 : more weight in the left tail of the distribution.
# - skewness < 0 : more weight in the right tail of the distribution.

# %%
num_cols_real = []

# %%
num_cols_real.extend(num_columns[:17])
num_cols_real.extend(num_columns[-4:])

# %%
case_list = {}

for col in num_cols_real:
    skewness = skew(to_plot[col].values)
    case = {col: skewness}
    case_list.update(case)
    
skew_df = pd.Series(case_list).to_frame().reset_index()
skew_df.columns = ["Column_Name", "Skewness"]
skew_df = skew_df.sort_values(by=["Skewness"], ascending=False)

# %%
skew_df
# Out:
#              Column_Name   Skewness
# 13        B_Decay_Energy  14.594679
# 14       dB_Decay_Energy  14.594679
# 10          dMass_Excess  14.594679
# 12       dBinding_Energy  14.594679
# 16    dAtomic_Mass_Micro  14.594679
# 9            Mass_Excess  14.594679
# 2                   Data   8.629346
# 3                  dData   8.604344
# 6                   Date   3.855392
# 17         Nuc_Radius_fm   1.000000
# 19     Compound_Neutrons   0.000000
# 20  Compound_Mass_Number   0.000000
# 8     Target_Mass_Number   0.000000
# 7        Target_Neutrons   0.000000
# 4         Target_Protons   0.000000
# 1                dEnergy  -0.111457
# 0                 Energy  -0.235082
# 18    Neut_Nuc_Rad_Ratio  -1.000000
# 5                   Year  -1.302264
# 15     Atomic_Mass_Micro -14.594679
# 11        Binding_Energy -14.594679

# %%
# In addition to all uncertanties
# skewed_cols = ["Binding_Energy", "ELV/HL", "Energy", "dBinding_Energy", "dELV/HL", "dEnergy"]
skewed_cols = ["Energy", "dEnergy"]

# %%
energy_log = np.log10(df["Energy"].values)
energy_ln = np.log(df["Energy"].values)

# %%
df[["Energy"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000190D1AAB1D0>]],
#       dtype=object)

# %%
plt.hist(energy_ln)
plt.show()

# %%
for col in skewed_cols:
    log_values = np.log10(df[col].values)
    df[col] = log_values

# %%
df["Year"] = df["Year"].astype(int)

# %% [markdown]
# # Categorical Data

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant is our calculated score value.</p>
#
# <p>If our data variable is strongly correlated with the variable we are analyzing, expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %%
grouped_test = df[['MT', 'Data']].groupby(['MT'])

f_val, p_val = stats.f_oneway(grouped_test.get_group("1")['Data'], grouped_test.get_group('101')['Data'], grouped_test.get_group('102')['Data'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 15917.016298247428 , P = 0.0

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation and a P value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?

# %%
def box_plot(x, dataframe=df, figsize=(8,6)):
    plt.figure(figsize=figsize)
    sns.boxplot(x=x, y="Data", data=dataframe)

# %%
box_plot("MT", figsize=(18,10))

# %% [markdown]
# The values for other reaction types get squashed do the large magnitude of fission and total cross section data points (MT1 and MT101). Still it is noticable that these cross sections are magnitudes higher than other types. This feature will be helpful in determining limits to some reaction types (it will learn not to go above certan values.

# %%
# call regplot on each axes
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(18,10))
sns.boxplot(x="Frame", y="Data", data=df, ax=ax1)
sns.boxplot(x="Target_Meta_State", y="Data", data=df, ax=ax2)
sns.boxplot(x="Product_Meta_State", y="Data", data=df, ax=ax3)
